# %%
import json
import matplotlib.pyplot as plt

# Step 1: Load the JSON file
with open('fees.json', 'r') as f:
    fees = json.load(f)

# Step 2: Plot the fees
plt.figure(figsize=(10, 6))
plt.plot(fees, marker='o', linestyle='-', color='b')
plt.title('Fee Values in Bips')
plt.xlabel('Index')
plt.ylabel('Fee in Bips')
plt.grid(True)

# Step 3: Display the plot
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load the JSON file
with open('volatility_updates.json', 'r') as f:
    data = json.load(f)

# Extract the block timestamps and new RV values
block_timestamps = [update['blockTimestamp'] for update in data["volatilityUpdates"]]
new_rv_values = [update['newRv'] for update in data["volatilityUpdates"]]

plt.figure(figsize=(12, 6))
plt.plot(block_timestamps, new_rv_values, marker='o', linestyle='-', color='g')
plt.title('Volatility (newRv) Over Time')
plt.xlabel('Block Timestamp')
plt.ylabel('newRv Value')
plt.grid(True)

plt.show()
